# %%
import pandas as np
import numpy as pd 
import matplotlib.pyplot as plt

# %%
hr1=np.read_csv('candidates.csv')
hr1
# Out:
#      Name  SSLC  HSC  Marketing  Statistics  HR  Production
# 0      x1    85   90         60          91   0           0
# 1      x2    75   56         75          65   0           0
# 2      x3    70   56         78          66   0           0
# 3      x4    55   78         98          50   0           0
# 4      x5    65   89         65          95   0           0
# ..    ...   ...  ...        ...         ...  ..         ...
# 115  x116    87   55         67          67   0           0
# 116  x117    87   59         89          45   0           0
# 117  x118    66   77         76          87   0           0
# 118  x119    76   78         86          49   0           0
# 119  x120    87   78         96          61   0           0
#
# [120 rows x 7 columns]

# %%
hr1.plot('Name', y=['SSLC','HSC','Marketing','Statistics','HR','Production'])
plt.title(" Candidates")
plt.show()

# %%
hr1.plot('Name', y=['HSC','Marketing','Statistics'])
plt.title(" Candidates")
plt.show()

# %%
hr1.plot('Name', y=['HSC','Statistics'])
plt.title(" Candidates")
plt.show()

# %%
hr1.loc[hr1.HSC >75, ['Name','HSC', 'Statistics']]
# Out:
#      Name  HSC  Statistics
# 0      x1   90          91
# 3      x4   78          50
# 4      x5   89          95
# 5      x6   77          45
# 6      x7   78          55
# ..    ...  ...         ...
# 113  x114   86          59
# 114  x115   97          89
# 117  x118   77          87
# 118  x119   78          49
# 119  x120   78          61
#
# [83 rows x 3 columns]

# %%
hr2=hr1.loc[hr1.Statistics >90, ['Name', 'Statistics']]
hr2
# Out:
#      Name  Statistics
# 0      x1          91
# 4      x5          95
# 36    x37          93
# 59    x60          93
# 60    x61          99
# 65    x66          94
# 87    x88          91
# 90    x91          99
# 96    x97          92
# 107  x108          91

# %%
hr_final=hr2['Name']
hr_final
# Out:
# 0        x1
# 4        x5
# 36      x37
# 59      x60
# 60      x61
# 65      x66
# 87      x88
# 90      x91
# 96      x97
# 107    x108
# Name: Name, dtype: object
