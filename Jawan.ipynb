# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt

# %%
jw=pd.read_csv("C:\\Users\\HP\\Desktop\\Datas\\jawan_teaser.csv")
jw
# Out:
#     Time  no_teaser_viewers
# 0      6                 24
# 1      7                 40
# 2      8                 16
# 3      9                  7
# 4     10                 78
# ..   ...                ...
# 62    20                245
# 63    21                278
# 64    22                289
# 65    23                199
# 66    24                210
#
# [67 rows x 2 columns]

# %%
jw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               67 non-null     int64
#  1   no_teaser_viewers  67 non-null     int64
# dtypes: int64(2)
# memory usage: 1.2 KB

# %%
jw.plot('Time', y=['no_teaser_viewers'])
plt.title("JAWAN")
plt.show()
