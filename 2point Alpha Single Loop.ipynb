# %%
import pandas as pd

# %%
egg=pd.read_csv("C:\\Users\\HP\\Desktop\\Datas\\eggs_single_exponential.csv")
egg
# Out:
#      Eggs_Sold
# 0        300.0
# 1        450.0
# 2        538.0
# 3        756.0
# 4        875.0
# ..         ...
# 129    19075.0
# 130    19220.6
# 131    19366.2
# 132    19511.8
# 133    19657.4
#
# [134 rows x 1 columns]

# %%
y=[egg]
y
# Out:
# [     Eggs_Sold
#  0        300.0
#  1        450.0
#  2        538.0
#  3        756.0
#  4        875.0
#  ..         ...
#  129    19075.0
#  130    19220.6
#  131    19366.2
#  132    19511.8
#  133    19657.4
#
#  [134 rows x 1 columns]]

# %%
y1=pd.DataFrame(egg,columns=['Eggs_Sold'])
y1
# Out:
#      Eggs_Sold
# 0        300.0
# 1        450.0
# 2        538.0
# 3        756.0
# 4        875.0
# ..         ...
# 129    19075.0
# 130    19220.6
# 131    19366.2
# 132    19511.8
# 133    19657.4
#
# [134 rows x 1 columns]

# %%
len(y1)
# Out:
# 134

# %%
y1.loc[0:1]
# Out:
#    Eggs_Sold
# 0      300.0
# 1      450.0

# %%
import numpy as np

# %%
y=np.array(y1)
y
# Out:
# array([[  300. ],
#        [  450. ],
#        [  538. ],
#        [  756. ],
#        [  875. ],
#        [ 1020.6],
#        [ 1166.2],
#        [ 1311.8],
#        [ 1457.4],
#        [ 1603. ],
#        [ 1748.6],
#        [ 1894.2],
#        [ 2039.8],
#        [ 2185.4],
#        [ 2331. ],
#        [ 2476.6],
#        [ 2622.2],
#        [ 2767.8],
#        [ 2913.4],
#        [ 3059. ],
#        [ 3204.6],
#        [ 3350.2],
#        [ 3495.8],
#        [ 3641.4],
#        [ 3787. ],
#        [ 3932.6],
#        [ 4078.2],
#        [ 4223.8],
#        [ 4369.4],
#        [ 4515. ],
#        [ 4660.6],
#        [ 4806.2],
#        [ 4951.8],
#        [ 5097.4],
#        [ 5243. ],
#        [ 5388.6],
#        [ 5534.2],
#        [ 5679.8],
#        [ 5825.4],
#        [ 5971. ],
#        [ 6116.6],
#        [ 6262.2],
#        [ 6407.8],
#        [ 6553.4],
#        [ 6699. ],
#        [ 6844.6],
#        [ 6990.2],
#        [ 7135.8],
#        [ 7281.4],
#        [ 7427. ],
#        [ 7572.6],
#        [ 7718.2],
#        [ 7863.8],
#        [ 8009.4],
#        [ 8155. ],
#        [ 8300.6],
#        [ 8446.2],
#        [ 8591.8],
#        [ 8737.4],
#        [ 8883. ],
#        [ 9028.6],
#        [ 9174.2],
#        [ 9319.8],
#        [ 9465.4],
#        [ 9611. ],
#        [ 9756.6],
#        [ 9902.2],
#        [10047.8],
#        [10193.4],
#        [10339. ],
#        [10484.6],
#        [10630.2],
#        [10775.8],
#        [10921.4],
#        [11067. ],
#        [11212.6],
#        [11358.2],
#        [11503.8],
#        [11649.4],
#        [11795. ],
#        [11940.6],
#        [12086.2],
#        [12231.8],
#        [12377.4],
#        [12523. ],
#        [12668.6],
#        [12814.2],
#        [12959.8],
#        [13105.4],
#        [13251. ],
#        [13396.6],
#        [13542.2],
#        [13687.8],
#        [13833.4],
#        [13979. ],
#        [14124.6],
#        [14270.2],
#        [14415.8],
#        [14561.4],
#        [14707. ],
#        [14852.6],
#        [14998.2],
#        [15143.8],
#        [15289.4],
#        [15435. ],
#        [15580.6],
#        [15726.2],
#        [15871.8],
#        [16017.4],
#        [16163. ],
#        [16308.6],
#        [16454.2],
#        [16599.8],
#        [16745.4],
#        [16891. ],
#        [17036.6],
#        [17182.2],
#        [17327.8],
#        [17473.4],
#        [17619. ],
#        [17764.6],
#        [17910.2],
#        [18055.8],
#        [18201.4],
#        [18347. ],
#        [18492.6],
#        [18638.2],
#        [18783.8],
#        [18929.4],
#        [19075. ],
#        [19220.6],
#        [19366.2],
#        [19511.8],
#        [19657.4]])

# %%
forcast = [y[0]]
alpha = .2
for i in range(1, len(y)):
    predict = alpha * y[i - 1] + (1 - alpha) * forcast[i - 1]
    forcast.append(predict)

forcast
# Out:
# [array([300.]),
#  array([300.]),
#  array([330.]),
#  array([371.6]),
#  array([448.48]),
#  array([533.784]),
#  array([631.1472]),
#  array([738.15776]),
#  array([852.886208]),
#  array([973.7889664]),
#  array([1099.63117312]),
#  array([1229.4249385]),
#  array([1362.3799508]),
#  array([1497.86396064]),
#  array([1635.37116851]),
#  array([1774.49693481]),
#  array([1914.91754785]),
#  array([2056.37403828]),
#  array([2198.65923062]),
#  array([2341.6073845]),
#  array([2485.0859076]),
#  array([2628.98872608]),
#  array([2773.23098086]),
#  array([2917.74478469]),
#  array([3062.47582775]),
#  array([3207.3806622]),
#  array([3352.42452976]),
#  array([3497.57962381]),
#  array([3642.82369905]),
#  array([3788.13895924]),
#  array([3933.51116739]),
#  array([4078.92893391]),
#  array([4224.38314713]),
#  array([4369.8665177]),
#  array([4515.37321416]),
#  array([4660.89857133]),
#  array([4806.43885706]),
#  array([4951.99108565]),
#  array([5097.55286852]),
#  array([5243.12229482]),
#  array([5388.69783585]),
#  array([5534.27826868]),
#  array([5679.86261495]),
#  array([5825.45009196]),
#  array([5971.04007357]),
#  array([6116.63205885]),
#  array([6262.22564708]),
#  array([6407.82051767]),
#  array([6553.41641413]),
#  array([6699.01313131]),
#  array([6844.61050504]),
#  array([6990.20840404]),
#  array([7135.80672323]),
#  array([7281.40537858]),
#  array([7427.00430287]),
#  array([7572.60344229]),
#  array([7718.20275383]),
#  array([7863.80220307]),
#  array([8009.40176245]),
#  array([8155.00140996]),
#  array([8300.60112797]),
#  array([8446.20090238]),
#  array([8591.8007219]),
#  array([8737.40057752]),
#  array([8883.00046202]),
#  array([9028.60036961]),
#  array([9174.20029569]),
#  array([9319.80023655]),
#  array([9465.40018924]),
#  array([9611.00015139]),
#  array([9756.60012111]),
#  array([9902.20009689]),
#  array([10047.80007751]),
#  array([10193.40006201]),
#  array([10339.00004961]),
#  array([10484.60003969]),
#  array([10630.20003175]),
#  array([10775.8000254]),
#  array([10921.40002032]),
#  array([11067.00001626]),
#  array([11212.600013]),
#  array([11358.2000104]),
#  array([11503.80000832]),
#  array([11649.40000666]),
#  array([11795.00000533]),
#  array([11940.60000426]),
#  array([12086.20000341]),
#  array([12231.80000273]),
#  array([12377.40000218]),
#  array([12523.00000175]),
#  array([12668.6000014]),
#  array([12814.20000112]),
#  array([12959.80000089]),
#  array([13105.40000071]),
#  array([13251.00000057]),
#  array([13396.60000046]),
#  array([13542.20000037]),
#  array([13687.80000029]),
#  array([13833.40000023]),
#  array([13979.00000019]),
#  array([14124.60000015]),
#  array([14270.20000012]),
#  array([14415.8000001]),
#  array([14561.40000008]),
#  array([14707.00000006]),
#  array([14852.60000005]),
#  array([14998.20000004]),
#  array([15143.80000003]),
#  array([15289.40000003]),
#  array([15435.00000002]),
#  array([15580.60000002]),
#  array([15726.20000001]),
#  array([15871.80000001]),
#  array([16017.40000001]),
#  array([16163.00000001]),
#  array([16308.60000001]),
#  array([16454.2]),
#  array([16599.8]),
#  array([16745.4]),
#  array([16891.]),
#  array([17036.6]),
#  array([17182.2]),
#  array([17327.8]),
#  array([17473.4]),
#  array([17619.]),
#  array([17764.6]),
#  array([17910.2]),
#  array([18055.8]),
#  array([18201.4]),
#  array([18347.]),
#  array([18492.6]),
#  array([18638.2]),
#  array([18783.8]),
#  array([18929.4])]

# %%
forecasted_sales = pd.DataFrame(forcast, columns=['forecast'])
forecasted_sales
# Out:
#      forecast
# 0      300.00
# 1      300.00
# 2      330.00
# 3      371.60
# 4      448.48
# ..        ...
# 129  18347.00
# 130  18492.60
# 131  18638.20
# 132  18783.80
# 133  18929.40
#
# [134 rows x 1 columns]

# %%
type(y1)
# Out:
# pandas.core.frame.DataFrame

# %%
actual=pd.DataFrame(y1, columns=['Eggs_Sold'])

# %%
actual
# Out:
#      Eggs_Sold
# 0        300.0
# 1        450.0
# 2        538.0
# 3        756.0
# 4        875.0
# ..         ...
# 129    19075.0
# 130    19220.6
# 131    19366.2
# 132    19511.8
# 133    19657.4
#
# [134 rows x 1 columns]

# %%
forecasted_sales
# Out:
#      forecast
# 0      300.00
# 1      300.00
# 2      330.00
# 3      371.60
# 4      448.48
# ..        ...
# 129  18347.00
# 130  18492.60
# 131  18638.20
# 132  18783.80
# 133  18929.40
#
# [134 rows x 1 columns]

# %%
type(actual)
# Out:
# pandas.core.frame.DataFrame

# %%
type(forecasted_sales)
# Out:
# pandas.core.frame.DataFrame

# %%
s=actual.loc[0:135]
s
# Out:
#      Eggs_Sold
# 0        300.0
# 1        450.0
# 2        538.0
# 3        756.0
# 4        875.0
# ..         ...
# 129    19075.0
# 130    19220.6
# 131    19366.2
# 132    19511.8
# 133    19657.4
#
# [134 rows x 1 columns]

# %%
t=forecasted_sales.loc[0:135]
t
# Out:
#      forecast
# 0      300.00
# 1      300.00
# 2      330.00
# 3      371.60
# 4      448.48
# ..        ...
# 129  18347.00
# 130  18492.60
# 131  18638.20
# 132  18783.80
# 133  18929.40
#
# [134 rows x 1 columns]

# %%
error=pd.merge(s, t, left_index=True, right_index=True)
error
# Out:
#      Eggs_Sold  forecast
# 0        300.0    300.00
# 1        450.0    300.00
# 2        538.0    330.00
# 3        756.0    371.60
# 4        875.0    448.48
# ..         ...       ...
# 129    19075.0  18347.00
# 130    19220.6  18492.60
# 131    19366.2  18638.20
# 132    19511.8  18783.80
# 133    19657.4  18929.40
#
# [134 rows x 2 columns]

# %%
error['Yt-Ft'] = error['Eggs_Sold'] - error['forecast']
error
# Out:
#      Eggs_Sold  forecast   Yt-Ft
# 0        300.0    300.00    0.00
# 1        450.0    300.00  150.00
# 2        538.0    330.00  208.00
# 3        756.0    371.60  384.40
# 4        875.0    448.48  426.52
# ..         ...       ...     ...
# 129    19075.0  18347.00  728.00
# 130    19220.6  18492.60  728.00
# 131    19366.2  18638.20  728.00
# 132    19511.8  18783.80  728.00
# 133    19657.4  18929.40  728.00
#
# [134 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
error.plot(y=['Eggs_Sold','forecast'])
plt.title("Eggs Vs. Forecasted Gain")
plt.show()

# %%
error['|Yt-Ft|'] = error['Yt-Ft'].abs()
error
# Out:
#      Eggs_Sold  forecast   Yt-Ft  |Yt-Ft|
# 0        300.0    300.00    0.00     0.00
# 1        450.0    300.00  150.00   150.00
# 2        538.0    330.00  208.00   208.00
# 3        756.0    371.60  384.40   384.40
# 4        875.0    448.48  426.52   426.52
# ..         ...       ...     ...      ...
# 129    19075.0  18347.00  728.00   728.00
# 130    19220.6  18492.60  728.00   728.00
# 131    19366.2  18638.20  728.00   728.00
# 132    19511.8  18783.80  728.00   728.00
# 133    19657.4  18929.40  728.00   728.00
#
# [134 rows x 4 columns]

# %%
#MAPE
error['|Yt-Ft|/Yt'] = error['|Yt-Ft|'] / error['Eggs_Sold']
error
# Out:
#      Eggs_Sold  forecast   Yt-Ft  |Yt-Ft|  |Yt-Ft|/Yt
# 0        300.0    300.00    0.00     0.00    0.000000
# 1        450.0    300.00  150.00   150.00    0.333333
# 2        538.0    330.00  208.00   208.00    0.386617
# 3        756.0    371.60  384.40   384.40    0.508466
# 4        875.0    448.48  426.52   426.52    0.487451
# ..         ...       ...     ...      ...         ...
# 129    19075.0  18347.00  728.00   728.00    0.038165
# 130    19220.6  18492.60  728.00   728.00    0.037876
# 131    19366.2  18638.20  728.00   728.00    0.037591
# 132    19511.8  18783.80  728.00   728.00    0.037311
# 133    19657.4  18929.40  728.00   728.00    0.037034
#
# [134 rows x 5 columns]

# %%
m=error.mean()
m
# Out:
# Eggs_Sold     9975.000000
# forecast      9274.440299
# Yt-Ft          700.559701
# |Yt-Ft|        700.559701
# |Yt-Ft|/Yt       0.119734
# dtype: float64
