# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mar=pd.read_csv('internal_marks.csv')
mar
# Out:
#    Year  Internal
# 0  2017        36
# 1  2018        37
# 2  2019        41
# 3  2020        38
# 4  2021        39
# 5  2022        40
# 6  2023        44

# %%
mar.shape
# Out:
# (7, 2)

# %%
mar.keys()
# Out:
# Index(['Year', 'Internal'], dtype='object')

# %%
mar.plot('Year', y='Internal')
plt.title(" Business Statistics Internal Marks")
plt.show()

# %%
final_view=pd.read_csv('cor_marks.csv')
final_view
# Out:
#    attendance  marks
# 0          59     68
# 1          67     75
# 2          78     85
# 3          95     95
# 4          85     90
# 5         100     98
# 6          67     78
# 7          67     77
# 8          67     79

# %%
final_view.corr()
# Out:
#             attendance     marks
# attendance    1.000000  0.984589
# marks         0.984589  1.000000

# %%
st=pd.read_csv('students.csv')

# %%
st
# Out:
#       boys  Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0     Ravi    Male     55       45         56       87       21         52
# 1     Jhon    male     75       55         40       64       90         61
# 2   Chandu    Male     25       54         89       76       95         87
# 3      Sam  Female     78       55         86       63       63         89
# 4  Likhith    Male     58       96         78       46       43         77
# 5   Chetan  Female     60       85         76       65       60         72
# 6   Pavani  Female     79       60         78       33       24         10
# 7   Murthy    Male     63       72         64       20       70         70
# 8   Shekar    Male     44       58         55       10       66         65
#
#    History  Civics
# 0       89      65
# 1       58      72
# 2       56      74
# 3       75      45
# 4       83      53
# 5       12       3
# 6       45      10
# 7       62      87
# 8       86      87

# %%
st.plot('boys', y=['Maths','Physics','English','Biology'])
plt.show()

# %%
bio=st[['boys','Biology','Physics']]
bio
# Out:
#       boys  Biology  Physics
# 0     Ravi       21       45
# 1     Jhon       90       55
# 2   Chandu       95       54
# 3      Sam       63       55
# 4  Likhith       43       96
# 5   Chetan       60       85
# 6   Pavani       24       60
# 7   Murthy       70       72
# 8   Shekar       66       58

# %%
bio.loc[bio.Biology >85, ['boys','Biology', 'Physics']]
# Out:
#      boys  Biology  Physics
# 1    Jhon       90       55
# 2  Chandu       95       54

# %%
mansoor1=pd.read_csv('cor_marks.csv')

# %%
mansoor1.corr()
# Out:
#             attendance     marks
# attendance    1.000000  0.984589
# marks         0.984589  1.000000

# %%
mar
# Out:
#    Year  Internal
# 0  2017        36
# 1  2018        37
# 2  2019        41
# 3  2020        38
# 4  2021        39
# 5  2022        40
# 6  2023        44

# %%
sns.set(style="whitegrid")
sns.boxplot(x="Internal",  data=mar)
# Out:
# <Axes: xlabel='Internal'>
