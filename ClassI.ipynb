# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pharma=pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\Datas\\trend.csv")

# %%
pharma=pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\datas\\trend.csv")
print(pharma.info())
print(pharma)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      34 non-null     int64
#  1   john      34 non-null     int64
#  2   narmadha  34 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 948.0 bytes
# None
#     Year     john    narmadha
# 0   1989  1197576    120000.0
# 1   1990  1053648    135000.0
# 2   1991  1124172    120000.0
# 3   1992   987144    105000.0
# 4   1993  1283616     90000.0
# 5   1994  1295100     75000.0
# 6   1995  1407444     60000.0
# 7   1996   922416     45000.0
# 8   1997  1272012     30000.0
# 9   1998  1064856     75899.0
# 10  1999  1269960     95000.0
# 11  2000  1064760     50000.0
# 12  2001  1207488     82500.0
# 13  2002  1186284     90410.1
# 14  2003  1231464     98320.2
# 15  2004  1296708    106230.3
# 16  2005  1320648    114140.4
# 17  2006  1102704    122050.5
# ...

# %%
pharma.plot('Year', y=['john', 'narmadha'])
plt.show()

# %%
pip install turtule
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement turtule (from versions: none)
# ERROR: No matching distribution found for turtule
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
