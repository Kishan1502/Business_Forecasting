# %%
import pandas as pd
import numpy as np
import warnings

# %%
GL_df=pd.read_csv('C:\\Users\\HP\\Desktop\\Datas\\GLAXO.csv')
GL_df
# Out:
#             Date     Open     High      Low    Last    Close  \
# 0     2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1     2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2     2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3     2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4     2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
# ...          ...      ...      ...      ...     ...      ...
# 1734  2016-12-26  2703.00  2740.00  2677.00  2715.0  2723.50
# 1735  2016-12-27  2722.95  2725.00  2683.00  2692.0  2701.75
# 1736  2016-12-28  2701.75  2718.00  2690.00  2698.0  2702.15
# 1737  2016-12-29  2702.05  2739.00  2691.95  2710.0  2727.90
# 1738  2016-12-30  2730.00  2740.45  2705.00  2730.0  2729.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                   9365.0           151.74
# 1                  38148.0           622.58
# 2                  36519.0           595.09
# 3                  12809.0           211.00
# 4                  28035.0           459.11
# ...                    ...              ...
# 1734                3953.0           107.15
# 1735               10600.0           286.10
# 1736                6050.0           163.44
# 1737                7649.0           207.87
# 1738                6513.0           177.65
#
# [1739 rows x 8 columns]

# %%
GL_df.describe
# Out:
# <bound method NDFrame.describe of             Date     Open     High      Low    Last    Close  \
# 0     2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1     2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2     2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3     2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4     2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
# ...          ...      ...      ...      ...     ...      ...
# 1734  2016-12-26  2703.00  2740.00  2677.00  2715.0  2723.50
# 1735  2016-12-27  2722.95  2725.00  2683.00  2692.0  2701.75
# 1736  2016-12-28  2701.75  2718.00  2690.00  2698.0  2702.15
# 1737  2016-12-29  2702.05  2739.00  2691.95  2710.0  2727.90
# 1738  2016-12-30  2730.00  2740.45  2705.00  2730.0  2729.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                   9365.0           151.74
# 1                  38148.0           622.58
# 2                  36519.0           595.09
# 3                  12809.0           211.00
# 4                  28035.0           459.11
# ...                    ...              ...
# 1734                3953.0           107.15
# 1735               10600.0           286.10
# 1736                6050.0           163.44
# 1737                7649.0           207.87
# 1738                6513.0           177.65
#
# [1739 rows x 8 columns]>

# %%
GL_df=GL_df[['Date', 'Close']]
GL_df
# Out:
#             Date    Close
# 0     2010-01-04  1625.65
# 1     2010-01-05  1616.80
# 2     2010-01-06  1638.50
# 3     2010-01-07  1648.70
# 4     2010-01-08  1639.80
# ...          ...      ...
# 1734  2016-12-26  2723.50
# 1735  2016-12-27  2701.75
# 1736  2016-12-28  2702.15
# 1737  2016-12-29  2727.90
# 1738  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
GL_df=GL_df.set_index(pd.DatetimeIndex(GL_df['Date']))
GL_df
# Out:
#                   Date    Close
# Date
# 2010-01-04  2010-01-04  1625.65
# 2010-01-05  2010-01-05  1616.80
# 2010-01-06  2010-01-06  1638.50
# 2010-01-07  2010-01-07  1648.70
# 2010-01-08  2010-01-08  1639.80
# ...                ...      ...
# 2016-12-26  2016-12-26  2723.50
# 2016-12-27  2016-12-27  2701.75
# 2016-12-28  2016-12-28  2702.15
# 2016-12-29  2016-12-29  2727.90
# 2016-12-30  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
GL_df.plot( y=['Close'])
plt.show()

# %%
GL_df['gain']=GL_df.Close.pct_change(periods=1)
GL_df.head(5)
# Out:
#                   Date    Close      gain
# Date
# 2010-01-04  2010-01-04  1625.65       NaN
# 2010-01-05  2010-01-05  1616.80 -0.005444
# 2010-01-06  2010-01-06  1638.50  0.013422
# 2010-01-07  2010-01-07  1648.70  0.006225
# 2010-01-08  2010-01-08  1639.80 -0.005398

# %%
GL_df=GL_df.dropna()
GL_df
# Out:
#                   Date    Close      gain
# Date
# 2010-01-05  2010-01-05  1616.80 -0.005444
# 2010-01-06  2010-01-06  1638.50  0.013422
# 2010-01-07  2010-01-07  1648.70  0.006225
# 2010-01-08  2010-01-08  1639.80 -0.005398
# 2010-01-11  2010-01-11  1629.45 -0.006312
# ...                ...      ...       ...
# 2016-12-26  2016-12-26  2723.50 -0.001283
# 2016-12-27  2016-12-27  2701.75 -0.007986
# 2016-12-28  2016-12-28  2702.15  0.000148
# 2016-12-29  2016-12-29  2727.90  0.009529
# 2016-12-30  2016-12-30  2729.80  0.000697
#
# [1738 rows x 3 columns]

# %%
plt.figure(figsize=(8,6))
plt.plot(GL_df.index, GL_df.gain)
plt.xlabel=('Time')
plt.ylabel=('gain')

# %%
round(GL_df.gain.mean(),4)
# Out:
# 0.0004

# %%
round(GL_df.gain.std(),4)
# Out:
# 0.0134

# %%
gain=GL_df
gain
# Out:
#                   Date    Close      gain
# Date
# 2010-01-05  2010-01-05  1616.80 -0.005444
# 2010-01-06  2010-01-06  1638.50  0.013422
# 2010-01-07  2010-01-07  1648.70  0.006225
# 2010-01-08  2010-01-08  1639.80 -0.005398
# 2010-01-11  2010-01-11  1629.45 -0.006312
# ...                ...      ...       ...
# 2016-12-26  2016-12-26  2723.50 -0.001283
# 2016-12-27  2016-12-27  2701.75 -0.007986
# 2016-12-28  2016-12-28  2702.15  0.000148
# 2016-12-29  2016-12-29  2727.90  0.009529
# 2016-12-30  2016-12-30  2729.80  0.000697
#
# [1738 rows x 3 columns]

# %%
gain['forecasted_gain']=gain.gain.rolling(2).mean()
gain
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20288\1750844643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gain['forecasted_gain']=gain.gain.rolling(2).mean()
#                   Date    Close      gain  forecasted_gain
# Date
# 2010-01-05  2010-01-05  1616.80 -0.005444              NaN
# 2010-01-06  2010-01-06  1638.50  0.013422         0.003989
# 2010-01-07  2010-01-07  1648.70  0.006225         0.009823
# 2010-01-08  2010-01-08  1639.80 -0.005398         0.000414
# 2010-01-11  2010-01-11  1629.45 -0.006312        -0.005855
# ...                ...      ...       ...              ...
# 2016-12-26  2016-12-26  2723.50 -0.001283         0.001846
# 2016-12-27  2016-12-27  2701.75 -0.007986        -0.004635
# 2016-12-28  2016-12-28  2702.15  0.000148        -0.003919
# 2016-12-29  2016-12-29  2727.90  0.009529         0.004839
# 2016-12-30  2016-12-30  2729.80  0.000697         0.005113
#
# [1738 rows x 4 columns]

# %%
gain=gain[['gain', 'forecasted_gain']]
gain
# Out:
#                 gain  forecasted_gain
# Date
# 2010-01-05 -0.005444              NaN
# 2010-01-06  0.013422         0.003989
# 2010-01-07  0.006225         0.009823
# 2010-01-08 -0.005398         0.000414
# 2010-01-11 -0.006312        -0.005855
# ...              ...              ...
# 2016-12-26 -0.001283         0.001846
# 2016-12-27 -0.007986        -0.004635
# 2016-12-28  0.000148        -0.003919
# 2016-12-29  0.009529         0.004839
# 2016-12-30  0.000697         0.005113
#
# [1738 rows x 2 columns]

# %%
gain.mean()#MSE
# Out:
# gain               0.000386
# forecasted_gain    0.000388
# dtype: float64

# %%
round(gain.gain.mean(),4)
# Out:
# 0.0004

# %%
gain['Yt-Ft'] = gain['gain'] - gain['forecasted_gain']
gain
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20288\361804080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gain['Yt-Ft'] = gain['gain'] - gain['forecasted_gain']
#                 gain  forecasted_gain     Yt-Ft
# Date
# 2010-01-05 -0.005444              NaN       NaN
# 2010-01-06  0.013422         0.003989  0.009433
# 2010-01-07  0.006225         0.009823 -0.003598
# 2010-01-08 -0.005398         0.000414 -0.005812
# 2010-01-11 -0.006312        -0.005855 -0.000457
# ...              ...              ...       ...
# 2016-12-26 -0.001283         0.001846 -0.003129
# 2016-12-27 -0.007986        -0.004635 -0.003351
# 2016-12-28  0.000148        -0.003919  0.004067
# 2016-12-29  0.009529         0.004839  0.004691
# 2016-12-30  0.000697         0.005113 -0.004416
#
# [1738 rows x 3 columns]

# %%
gain.plot(y=['gain','forecasted_gain'])
plt.title("Gain Vs. Forecasted Gain")
plt.show()

# %%
gain['|Yt-Ft|'] = gain['Yt-Ft'].abs()
gain
# Out:
#                 gain  forecasted_gain     Yt-Ft   |Yt-Ft|
# Date
# 2010-01-05 -0.005444              NaN       NaN       NaN
# 2010-01-06  0.013422         0.003989  0.009433  0.009433
# 2010-01-07  0.006225         0.009823 -0.003598  0.003598
# 2010-01-08 -0.005398         0.000414 -0.005812  0.005812
# 2010-01-11 -0.006312        -0.005855 -0.000457  0.000457
# ...              ...              ...       ...       ...
# 2016-12-26 -0.001283         0.001846 -0.003129  0.003129
# 2016-12-27 -0.007986        -0.004635 -0.003351  0.003351
# 2016-12-28  0.000148        -0.003919  0.004067  0.004067
# 2016-12-29  0.009529         0.004839  0.004691  0.004691
# 2016-12-30  0.000697         0.005113 -0.004416  0.004416
#
# [1738 rows x 4 columns]

# %%
#MAPE
gain['|Yt-Ft|/Yt'] = gain['|Yt-Ft|'] / gain['gain']
gain
# Out:
#                 gain  forecasted_gain     Yt-Ft   |Yt-Ft|  |Yt-Ft|/Yt
# Date
# 2010-01-05 -0.005444              NaN       NaN       NaN         NaN
# 2010-01-06  0.013422         0.003989  0.009433  0.009433    0.702807
# 2010-01-07  0.006225         0.009823 -0.003598  0.003598    0.578002
# 2010-01-08 -0.005398         0.000414 -0.005812  0.005812   -1.076601
# 2010-01-11 -0.006312        -0.005855 -0.000457  0.000457   -0.072369
# ...              ...              ...       ...       ...         ...
# 2016-12-26 -0.001283         0.001846 -0.003129  0.003129   -2.438166
# 2016-12-27 -0.007986        -0.004635 -0.003351  0.003351   -0.419643
# 2016-12-28  0.000148        -0.003919  0.004067  0.004067   27.470379
# 2016-12-29  0.009529         0.004839  0.004691  0.004691    0.492232
# 2016-12-30  0.000697         0.005113 -0.004416  0.004416    6.340890
#
# [1738 rows x 5 columns]

# %%
m=gain.mean()
m
# Out:
# gain               0.000386
# forecasted_gain    0.000388
# Yt-Ft              0.000002
# |Yt-Ft|            0.006028
# |Yt-Ft|/Yt              inf
# dtype: float64

# %%
gain.mean()#MSE
# Out:
# gain               0.000386
# forecasted_gain    0.000388
# Yt-Ft              0.000002
# |Yt-Ft|            0.006028
# |Yt-Ft|/Yt              inf
# dtype: float64
