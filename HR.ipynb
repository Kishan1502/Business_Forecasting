# %%
import pandas as pd

# %%
hr=pd.read_csv('HR_Cost.csv')
hr
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\HP\Desktop\py_codes\HR.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/py_codes/HR.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> hr=pd.read_csv('HR_Cost.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/py_codes/HR.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> hr
#
# ...

# %%
hr['forecasted_Cost']=hr.Cost.rolling(2).mean()
hr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP\Desktop\py_codes\HR.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/py_codes/HR.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> hr['forecasted_Cost']=hr.Cost.rolling(2).mean()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/py_codes/HR.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> hr
#
# NameError: name 'hr' is not defined

# %%
hr.loc[0]=[202,205]
hr
# Out:
#      Cost  forecasted_Cost
# 0     202            205.0
# 1     208            205.0
# 2     222            215.0
# 3     219            220.5
# 4     211            215.0
# ..    ...              ...
# 139   696            704.0
# 140   598            647.0
# 141   551            574.5
# 142   480            515.5
# 143   522            501.0
#
# [144 rows x 2 columns]

# %%
hr=hr.rename(columns={'Cost': 'Costs'})
hr
# Out:
#      Costs  forecasted_Cost
# 0      202            205.0
# 1      208            205.0
# 2      222            215.0
# 3      219            220.5
# 4      211            215.0
# ..     ...              ...
# 139    696            704.0
# 140    598            647.0
# 141    551            574.5
# 142    480            515.5
# 143    522            501.0
#
# [144 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
hr.plot(y=['Costs','forecasted_Cost'])
plt.title("Costs Vs. Forecasted Cost")
plt.show()

# %%
hr['Yt-Ft'] = hr['Costs'] - hr['forecasted_Cost']
hr
# Out:
#      Costs  forecasted_Cost  Yt-Ft
# 0      202            205.0   -3.0
# 1      208            205.0    3.0
# 2      222            215.0    7.0
# 3      219            220.5   -1.5
# 4      211            215.0   -4.0
# ..     ...              ...    ...
# 139    696            704.0   -8.0
# 140    598            647.0  -49.0
# 141    551            574.5  -23.5
# 142    480            515.5  -35.5
# 143    522            501.0   21.0
#
# [144 rows x 3 columns]

# %%
hr['|Yt-Ft|'] = hr['Yt-Ft'].abs()
hr
# Out:
#      Costs  forecasted_Cost  Yt-Ft  |Yt-Ft|
# 0      202            205.0   -3.0      3.0
# 1      208            205.0    3.0      3.0
# 2      222            215.0    7.0      7.0
# 3      219            220.5   -1.5      1.5
# 4      211            215.0   -4.0      4.0
# ..     ...              ...    ...      ...
# 139    696            704.0   -8.0      8.0
# 140    598            647.0  -49.0     49.0
# 141    551            574.5  -23.5     23.5
# 142    480            515.5  -35.5     35.5
# 143    522            501.0   21.0     21.0
#
# [144 rows x 4 columns]

# %%
hr['|Yt-Ft|/Yt'] = hr['|Yt-Ft|'] / hr['Costs']
hr
# Out:
#      Costs  forecasted_Cost  Yt-Ft  |Yt-Ft|  |Yt-Ft|/Yt
# 0      202            205.0   -3.0      3.0    0.014851
# 1      208            205.0    3.0      3.0    0.014423
# 2      222            215.0    7.0      7.0    0.031532
# 3      219            220.5   -1.5      1.5    0.006849
# 4      211            215.0   -4.0      4.0    0.018957
# ..     ...              ...    ...      ...         ...
# 139    696            704.0   -8.0      8.0    0.011494
# 140    598            647.0  -49.0     49.0    0.081940
# 141    551            574.5  -23.5     23.5    0.042650
# 142    480            515.5  -35.5     35.5    0.073958
# 143    522            501.0   21.0     21.0    0.040230
#
# [144 rows x 5 columns]

# %%
hr.loc[:, '|Yt-Ft|'].mean()
# Out:
# 12.88888888888889

# %%
hr.loc[:, '|Yt-Ft|/Yt'].mean()
# Out:
# 0.03308848066285671

# %%
m= hr['Yt-Ft']**2
m
# Out:
# 0         9.00
# 1         9.00
# 2        49.00
# 3         2.25
# 4        16.00
#         ...
# 139      64.00
# 140    2401.00
# 141     552.25
# 142    1260.25
# 143     441.00
# Name: Yt-Ft, Length: 144, dtype: float64

# %%
m.mean()#MSE
# Out:
# 282.7291666666667
