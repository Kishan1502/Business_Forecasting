# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mar=pd.read_excel("C:\\Users\\HP\\OneDrive\\Desktop\\Datas\\markss.xlsx")
mar
# Out:
#    Year  Internal Marks
# 0  2017              36
# 1  2018              37
# 2  2019              41
# 3  2020              38
# 4  2021              39
# 5  2022              40
# 6  2023              44

# %%
mar.plot('Year', y='Internal Marks')
plt.title(" Business Statistics Internal Marks")
plt.show()

# %%
mar.corr()
# Out:
#                     Year  Internal Marks
# Year            1.000000        0.802955
# Internal Marks  0.802955        1.000000
