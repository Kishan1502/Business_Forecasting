# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bvc=pd.read_excel("C:\\Users\\HP\\Desktop\\Datas\\beverage.xlsx")
bvc
# Out:
#     YEAR      SALES  EXPENSES  FORECASTED SALES  FORECASTED
# 0   13.0  4447581.0     160.0               NaN          NaN
# 1   14.0  3675305.0     130.0               NaN          NaN
# 2   15.0  3477156.0     130.0               NaN          NaN
# 3   16.0  3720794.0     140.0               NaN          NaN
# 4   17.0  3834086.0     167.0      4.447581e+06        160.0
# 5   18.0  3888913.0     148.0      4.061443e+06        145.0
# 6   19.0  3871342.0     150.0      3.866681e+06        140.0
# 7   20.0  3679862.0     129.0      3.830209e+06        140.0
# 8   21.0  3358242.0     120.0      3.830984e+06        145.4
# 9   22.0  3361488.0     122.0      3.719251e+06        143.0
# 10  23.0  3670362.0     135.0      3.758458e+06        147.0
# 11  24.0  3123966.0     110.0      3.798999e+06        146.8
# 12  25.0  4634047.0     165.0      3.726489e+06        142.8
# 13  26.0  3772879.0     129.0      3.631969e+06        133.8
# ...

# %%
bvc.plot('YEAR' , y=['SALES' , 	'EXPENSES' , 'FORECASTED SALES' , 'FORECASTED '])
plt.show()
