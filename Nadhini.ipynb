# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nan=pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\Datas\\nandhini.csv")
nan
# Out:
#     Weeks  tonned
# 0       1      20
# 1       2      10
# 2       3       8
# 3       4       9
# 4       5       7
# 5       6      12
# 6       7      11
# 7       8       9
# 8       9       8
# 9      10       7
# 10     11      20
# 11     12      15
# 12     13       8
# 13     14       8
# 14     15       7
# 15     16      18
# 16     17      12
# 17     18       8
# 18     19       8
# 19     20       7
# 20     21      20
# 21     22      10
# 22     23       8
# 23     24       9
# 24     25       7
# 25     26      20
# 26     27      10
# 27     28       8
# 28     29       9
# 29     30       7
# 30     31      20
# 31     32      10
# 32     33       8
# 33     34       9
# 34     17       7
# 35     36      18
# 36     37       9
# 37     38       9
# 38     39       8
# 39     40       6
# 40     41      20
# 41     42      10
# 42     43       8
# 43     44       9
# 44     45       7
# 45     46      18
# 46     47      10
# 47     48       9
# 48     49       8
# ...

# %%
nan.corr()
# Out:
#            Weeks    tonned
# Weeks   1.000000 -0.072783
# tonned -0.072783  1.000000

# %%
nan.plot('Weeks', y='tonned')
plt.title(" Correlation")
plt.show()
